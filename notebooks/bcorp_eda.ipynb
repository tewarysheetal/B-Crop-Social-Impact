# %%
print((df['current_status'] == 'certified').sum())
# Out:
# 10754

# %%
for col in df.columns:    
    print(col, " | missing:", df[col].isnull().sum(), " | unique:", df[col].nunique())
# Out:
# index  | missing: 0  | unique: 13694
# company_id  | missing: 0  | unique: 8946
# company_name  | missing: 1  | unique: 8940
# date_first_certified  | missing: 0  | unique: 2904
# date_certified  | missing: 0  | unique: 10178
# current_status  | missing: 0  | unique: 2
# description  | missing: 4  | unique: 8943
# industry  | missing: 0  | unique: 164
# industry_category  | missing: 0  | unique: 22
# products_and_services  | missing: 3339  | unique: 5346
# country  | missing: 0  | unique: 97
# state  | missing: 33  | unique: 896
# city  | missing: 15  | unique: 2799
# sector  | missing: 0  | unique: 6
# size  | missing: 0  | unique: 7
# b_corp_profile  | missing: 0  | unique: 8946
# website  | missing: 60  | unique: 8892
# assessment_year  | missing: 0  | unique: 17
# overall_score  | missing: 0  | unique: 780
# impact_area_community  | missing: 0  | unique: 782
# impact_area_customers  | missing: 356  | unique: 669
# impact_area_environment  | missing: 0  | unique: 621
# ...

# %%
print(df.isnull().sum().sort_values(ascending=False).head(50))
# Out:
# ia_customers_it_infrastructure_market_access                          13687
# ia_customers_it_mission_aligned_exit                                  13686
# ia_environment_it_environmentally_innovative_agricultural_process     13686
# ia_customers_it_student_experience                                    13679
# ia_customers_it_marketing_recruiting_and_transparency                 13678
# ia_environment_it_designed_to_conserve_wholesale_process              13674
# ia_environment_it_green_investing                                     13644
# ia_community_it_national_economic_development                         13636
# ia_customers_it_infrastructure_market_access_building                 13631
# ia_environment_it_environmentally_innovative_manufacturing_process    13631
# ia_customers_it_educational_models_and_engagement                     13622
# ia_community_it_microfranchise_poverty_alleviation                    13622
# ...

# %%
print(df.columns.tolist())
# Out:
# ['index', 'company_id', 'company_name', 'date_first_certified', 'date_certified', 'current_status', 'description', 'industry', 'industry_category', 'products_and_services', 'country', 'state', 'city', 'sector', 'size', 'b_corp_profile', 'website', 'assessment_year', 'overall_score', 'impact_area_community', 'impact_area_customers', 'impact_area_environment', 'impact_area_governance', 'impact_area_workers', 'impact_area_community_na_score', 'impact_area_customers_na_score', 'impact_area_environment_na_score', 'impact_area_governance_na_score', 'impact_area_workers_na_score', 'ia_community_it_civic_engagement_giving', 'ia_community_it_designed_for_charitable_giving', 'ia_community_it_designed_to_give', 'ia_community_it_diversity_equity_inclusion', 'ia_community_it_diversity_inclusion', 'ia_community_it_economic_impact', 'ia_community_it_job_creation', 'ia_community_it_local_economic_development', 'ia_community_it_local_involvement', 'ia_community_it_microdistribution_poverty_alleviatio
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13694 entries, 0 to 13693
# Columns: 135 entries, index to certification_cycle
# dtypes: float64(117), int64(2), str(16)
# memory usage: 14.1 MB
# None

# %%
print(df.head())
# Out:
#    index          company_id       company_name date_first_certified  \
# 0      0  001C000001cjG1nIAE               B1G1           2017-10-11
# 1      1  001C000001cjG1nIAE               B1G1           2017-10-11
# 2      2  0013b00001p3n7tAAA                RPM           2021-02-08
# 3      3  001C000001fH72gIAC         Kingsfleet           2022-05-18
# 4      4  001C000001cjg3CIAQ  Impact Hub Boston           2019-07-02
#
#                      date_certified current_status  \
# 0  2021-05-27 04:07:25.168843+00:00      certified
# 1         2017-10-11 00:00:00+00:00      certified
# 2  2021-02-08 03:35:47.601595+00:00      certified
# 3  2022-05-18 14:13:36.866684+00:00      certified
# 4  2019-07-02 18:44:47.440164+00:00   de-certified
#
#                                          description  \
# 0  B1G1 runs a business movement that enables bus...
# 1  B1G1 runs a business movement that enables bus...
# 2  RPM is an independent creative experience agen...
# ...

# %%
print(df.shape)
# Out:
# (13694, 135)

# %%
import pandas as pd
df = pd.read_csv("D:\\Projects\\B-Crop-Social-Impact\\data\\raw\\B-Corp-Impact-Data.csv")
